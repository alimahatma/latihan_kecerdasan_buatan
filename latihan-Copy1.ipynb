# %%
hitung = 0
while(hitung < 1000):
    hitung = hitung + 1
    print("aku suka STMIK LOMBOK")
# Out:
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# aku suka STMIK LOMBOK
# ...

# %%
hitung = 0
while (hitung < 3):
    hitung = hitung + 1
    print("Jurusan SIstem Informasi")
else:
    print("Jurusan Teknik Informatika")
# Out:
# Jurusan SIstem Informasi
# Jurusan SIstem Informasi
# Jurusan SIstem Informasi
# Jurusan Teknik Informatika

# %%
angka = [1, 2,3,4,5]
for x  in angka:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
prodi = ["Sistem Informasi","Teknik Informatika","Bisnis Digital","Telekomunikasi"]
for jurusan in prodi:
    print("Daftar jurusan di STMIK LOMBOK : ", jurusan)
# Out:
# Daftar jurusan di STMIK LOMBOK :  Sistem Informasi
# Daftar jurusan di STMIK LOMBOK :  Teknik Informatika
# Daftar jurusan di STMIK LOMBOK :  Bisnis Digital
# Daftar jurusan di STMIK LOMBOK :  Telekomunikasi

# %%
Mahasiswa = ["Mahidin","Saikin","ALI"]
Matakuliah = ["Data Mining","Kecerdasan BUatan","PBO"]

for mhs in Mahasiswa:
    for makul in Matakuliah:
        print (mhs, "Mengambil Matakuliah", makul)
# Out:
# Mahidin Mengambil Matakuliah Data Mining
# Mahidin Mengambil Matakuliah Kecerdasan BUatan
# Mahidin Mengambil Matakuliah PBO
# Saikin Mengambil Matakuliah Data Mining
# Saikin Mengambil Matakuliah Kecerdasan BUatan
# Saikin Mengambil Matakuliah PBO
# ALI Mengambil Matakuliah Data Mining
# ALI Mengambil Matakuliah Kecerdasan BUatan
# ALI Mengambil Matakuliah PBO

# %%
def my_function ():
    print("Hellloo")
